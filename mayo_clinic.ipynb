# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs

# %%
MC_URL = 'https://www.mayoclinic.org'
SC_URL = '/symptom-checker/select-symptom/itt-20009075'

def extract_mayo_clinic_symptoms():
    req = Request(MC_URL + SC_URL, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    soup = bs(webpage)
    adult_symptom_list = soup.find('div', {'class': 'adult'})
        
    return [{
        'name': a.text, 
        'url': a['href'], 
        'factors': extract_factors(a['href'])
    } for a in adult_symptom_list.find_all('a')]

def extract_factors(symptom_url):
    req = Request(MC_URL + symptom_url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    soup = bs(webpage)
    fieldsets = soup.find_all('fieldset')
    return [[fieldset.find('legend').text, [label.text for label in fieldset.find_all('label')]] for fieldset in fieldsets]

# %%
symptoms = extract_mayo_clinic_symptoms()

# %%
import json
with open('mayo_clinic_symptoms.json', 'w') as f:
    json.dump(symptoms, f)

# %%
import json
with open('mayo_clinic_symptoms.json') as f:
    symptoms = json.load(f)

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en_core_web_sm')

printed = set()
for symptom in symptoms:
    for prompt, factors in symptom['factors']:
        doc = nlp(prompt)
        pos = [token.pos_ for token in doc]
        tag = [token.tag_ for token in doc]
        if prompt not in printed:
            printed.add(prompt)
            print(prompt)
            print(' '.join(pos))
            print(factors)
            
            START = "IS"
            SYMPTOM = {symptom['name']}
            POSESSIVE = "YOUR"
            modified_doc = doc
            modified_doc_texts = [tok.text for tok in doc]
            
            PN_index = pos.index('PROPN') if 'PROPN' in pos else -1
            N_index = PN_index if PN_index > -1 else (pos.index('NOUN') if 'NOUN' in pos else -1)

            # IS/DOES NOUN...?
            if N_index > -1 and doc[N_index].text != 'use':
                SYMPTOM = ""
                
                if tag[N_index] == 'NNS':
                    START = "ARE"
                if pos[-1] == "VERB" and modified_doc_texts[-1] != 'located':
                    modified_doc_texts[-1] = modified_doc[-1].lemma_

            V_index = pos.index('VERB') if 'VERB' in pos else -1
            # IS VERB-ing...?
            if V_index > -1 and not doc[V_index].text.endswith("ed"):
                START = "DOES"
                if modified_doc_texts[0].lower() == 'you' or (N_index > -1 and tag[N_index] == 'NNS'):
                    START = 'DO'
                    POSESSIVE = ''
                    SYMPTOM = ''
                    
            if pos[-1] == 'AUX':
                modified_doc_texts = modified_doc_texts[:-1]
            
            # Singular cases
            if pos[0] == 'VERB' and len(pos) == 1 and doc[0].text != "Located":
                POSESSIVE = ''
                SYMPTOM = ''
            
            if prompt == 'Pain best described as':
                START = "IS"
                SYMPTOM = ''
            
            print(f"{START} {POSESSIVE} {SYMPTOM} {' '.join(modified_doc_texts)}...")
            print()
            print('_____')
            print()
# Out:
# Pain is
# NOUN AUX
# ['Burning', 'Crampy', 'Dull', 'Gnawing', 'Intense', 'Intermittent or episodic', 'Ongoing (chronic)', 'Sharp', 'Steady', 'Sudden (acute)', 'Worsening or progressing']
# IS YOUR  Pain...
#
# _____
#
# Pain located in
# NOUN VERB ADP
# ['Abdomen but radiates to other parts of the body', 'Lower abdomen', 'Middle abdomen', 'One or both sides', 'Upper abdomen']
# IS YOUR  Pain located in...
#
# _____
#
# Triggered or worsened by
# VERB CCONJ VERB ADP
# ['Coughing or other jarring movements', 'Drinking alcohol', 'Eating certain foods', 'Menstrual cycle', 'Stress']
# IS YOUR {'Abdominal pain in adults'} Triggered or worsened by...
#
# _____
#
# Relieved by
# VERB ADP
# ['Antacids', 'Avoiding certain foods', 'Changing position', 'Drinking more water', 'Eating certain foods', 'Eating more fiber']
# IS YOUR {'Abdominal pain in adults'} Relieved by...
#
# _____
#
# Accompanied by
# VERB ADP
# ['Abdominal swelling', 'Black or bloody stools', 'Constipation', 'Diarrhea', 'Fever', 'Inability to move bowels in spite of urge', 'Loose, watery stools', 'Nausea or vomiting', 'Passing gas', 'Pulsing sensation near the navel', 'Rash', 'Stomach growling or rumbling', 'Unintended weight loss', 'Urgent need to have a bowel movement']
# IS YOUR {'Abdominal pain in adults'} Accompanied by...
#
# _____
#
# Blood appears
# NOUN VERB
# ['In or on the stool', 'In toilet bowl or on toilet tissue']
# DOES YOUR  Blood appear...
#
# _____
#
# Pain best described as
# VERB ADV VERB SCONJ
# ['Achy or gnawing', 'Burning', 'Severe', 'Sharp', 'Squeezing or pressure', 'Sudden', 'Tight']
# IS YOUR  Pain best described as...
#
# _____
#
# Problem is
# NOUN AUX
# ['Ongoing or recurrent', 'Preceded by upper respiratory illness']
# IS YOUR  Problem...
#
# _____
#
# Cough is
# NOUN AUX
# ['Dry', 'Producing phlegm or sputum']
# IS YOUR  Cough...
#
# _____
#
# Preceded by
# VERB ADP
# ['Eating suspect food', 'Recent antibiotic use']
# IS YOUR {'Diarrhea in adults'} Preceded by...
#
# _____
#
# Swallowing
# VERB
# ['Hurts', 'Takes effort']
# DOES   Swallowing...
#
# _____
#
# You feel
# PRON VERB
# ['A spinning sensation', 'Lightheaded or faint', 'Unsteady']
# DO   You feel...
#
# _____
#
# Symptoms are
# NOUN AUX
# ['New or sudden', 'Recurrent or ongoing']
# ARE YOUR  Symptoms...
#
# _____
#
# Eye discomfort best described as
# NOUN NOUN ADV VERB SCONJ
# ['Achy', 'Dry or itchy', 'Gritty sensation', 'Redness without actual discomfort', 'Sensitivity to light', 'Severe pain', 'Stinging or burning sensation']
# IS YOUR  Eye discomfort best described as...
#
# _____
#
# Appearance of eye includes
# NOUN ADP NOUN VERB
# ['Bleeding on the surface of the white of the eye', 'Crusted eyelashes after sleeping', 'Excessive tearing', 'Red, painful lump on the eyelid', 'Redness', 'Stringy mucus in or around the eye', 'Swelling around the eye']
# DOES YOUR  Appearance of eye include...
#
# _____
#
# Vision problem includes
# NOUN NOUN VERB
# ['Blurred vision', 'Dark, floating spots in vision', 'Vision loss']
# DOES YOUR  Vision problem include...
#
# _____
#
# Triggered by
# VERB ADP
# ['Allergens or other irritants', 'Injury or trauma']
# IS YOUR {'Eye discomfort and redness in adults'} Triggered by...
#
# _____
#
# Worsened by
# VERB ADP
# ['Dry, warm air', 'Eye movement']
# IS YOUR {'Eye discomfort and redness in adults'} Worsened by...
#
# _____
#
# Problem affects
# NOUN VERB
# ['Both eyes', 'One eye']
# DOES YOUR  Problem affect...
#
# _____
#
# Vision improves somewhat with
# NOUN VERB ADV ADP
# ['Holding objects away from face', 'Holding objects close to face', 'Squinting', 'Use of bright lighting']
# DOES YOUR  Vision improves somewhat with...
#
# _____
#
# Onset is
# PROPN AUX
# ['Gradual or progressive', 'Recent (hours to days)', 'Sudden (seconds to minutes)']
# IS YOUR  Onset...
#
# _____
#
# Duration is
# NOUN AUX
# ['A few minutes', 'Usually no longer than 30 minutes']
# IS YOUR  Duration...
#
# _____
#
# Located in
# VERB ADP
# ['Ankle', 'Area along edge of toenail', 'Back of ankle', 'Bottom of foot', 'Heel', 'Middle part of foot', 'Toe or front part of foot', 'Whole foot']
# IS YOUR {'Foot pain or ankle pain in adults'} Located in...
#
# _____
#
# Swelling occurs
# NOUN VERB
# ['Along whole limb', 'Around ankle or foot', 'Around knee', 'In both limbs', 'In one limb']
# DOES YOUR  Swelling occur...
#
# _____
#
# Pain located
# NOUN VERB
# ['Around one eye or radiates from one eye', 'Around your temples', 'On both sides of your head', 'On one side of your head']
# IS YOUR  Pain located...
#
# _____
#
# Duration of headache is
# PROPN ADP PROPN AUX
# ['A few hours to days', 'A few minutes to hours']
# IS YOUR  Duration of headache...
#
# _____
#
# Recurrence of headache
# NOUN ADP PROPN
# ['Gradually becomes more frequent', 'Is daily', 'Is often the same time every day']
# IS YOUR  Recurrence of headache...
#
# _____
#
# Palpitations often occur when
# NOUN ADV VERB ADV
# ["You're anxious or stressed", "You're exerting yourself", "You're resting or going to bed"]
# DO   Palpitations often occur when...
#
# _____
#
# Heart rate is
# NOUN NOUN AUX
# ['Faster than normal', 'Irregular or not steady', 'Slower than normal']
# IS YOUR  Heart rate...
#
# _____
#
# Preceded by use of
# VERB ADP NOUN ADP
# ['Caffeine or alcohol', 'Cigarettes or recreational drugs', 'Medications or herbal supplements']
# IS YOUR {'Heart palpitations in adults'} Preceded by use of...
#
# _____
#
# Located
# VERB
# ['Along one or both sides of the knee', 'Around the kneecap', 'Behind the knee', 'In the knee joint']
# IS YOUR {'Knee pain in adults'} Located...
#
# _____
#
# Pain
# NOUN
# ['Began suddenly', 'Gradually worsens', 'Started gradually']
# IS YOUR  Pain...
#
# _____
#
# Nasal congestion is
# NOUN NOUN AUX
# ['New or recent', 'Ongoing or persistent']
# IS YOUR  Nasal congestion...
#
# _____
#
# Nasal discharge is
# NOUN NOUN AUX
# ['Clear or watery', 'Yellow or greenish']
# IS YOUR  Nasal discharge...
#
# _____
#
# Pain started
# NOUN VERB
# ['Gradually', 'Suddenly']
# IS YOUR  Pain start...
#
# _____
#
# Numbness or tingling
# NOUN CCONJ VERB
# ['Affects your fingers or hand', 'Is intermittent', 'Started gradually', 'Wakes you up at night']
# DOES YOUR  Numbness or tingle...
#
# _____
#
# Related pain involves
# ADJ NOUN VERB
# ['Itching or burning around genitals, buttocks or inner thighs', 'Pain in back or side', 'Pain in lower abdomen or groin', 'Painful ejaculation', 'Painful sexual intercourse']
# DOES YOUR  Related pain involve...
#
# _____
#
# Wheezing is
# NOUN AUX
# ['New or recent', 'Ongoing or recurrent']
# IS YOUR  Wheezing...
#
# _____
